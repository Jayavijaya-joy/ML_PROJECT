# %%
import pandas as pd
df=pd.read_csv("heart.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.describe(include="O")
# Out:
#         Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# count   918           918        918            918      918
# unique    2             4          3              2        3
# top       M           ASY     Normal              N     Flat
# freq    725           496        552            547      460

# %% [markdown]
# ## ENCODING---USED CHANGE TEXT TO NUMERICAL

# %%
data = pd.get_dummies(df.Sex,prefix='Gender',drop_first=True)
df=pd.concat([data,df],axis=1)
df.drop(columns="Sex",inplace=True)

# %%
data=pd.get_dummies(df.ChestPainType, prefix='ChestPain',drop_first=True)
df=pd.concat([data,df],axis=1)
df.drop(columns="ChestPainType",inplace=True)

# %%
data=pd.get_dummies(df.RestingECG, prefix='RestingECG',drop_first=True)
df=pd.concat([data,df],axis=1)
df.drop(columns="RestingECG",inplace=True)

# %%
data=pd.get_dummies(df.ExerciseAngina, prefix='ExerciseAngina',drop_first=True)
df=pd.concat([data,df],axis=1)
df.drop(columns="ExerciseAngina",inplace=True)

# %%
data=pd.get_dummies(df.ST_Slope, prefix='ST_Slope',drop_first=True)
df=pd.concat([data,df],axis=1)
df.drop(columns="ST_Slope",inplace=True)

# %%
df
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [918 rows x 16 columns]

# %% [markdown]
# ## OUTLIER HANDLING --- to remove unusual data point , data>LB AND data<UB

# %% [markdown]
# ## Age

# %%
from scipy import stats
stats.iqr(df.Age)
# Out:
# 13.0

# %%
IQR_Age=stats.iqr(df.Age)

# %%
import numpy as np

# %%
Q1_Age = np.percentile(df.Age,25)
Q3_Age = np.percentile(df.Age,75)
print(Q1_Age)
print(Q3_Age)
# Out:
# 47.0
# 60.0

# %%
Q1_Age - 1.5*(IQR_Age)
# Out:
# 27.5

# %%
Q3_Age + 1.5*(IQR_Age)
# Out:
# 79.5

# %%
LB_Age=Q1_Age - 1.5*(IQR_Age)
UB_Age=Q3_Age + 1.5*(IQR_Age)

# %%
df[(df.Age>LB_Age) &(df.Age<UB_Age)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [918 rows x 16 columns]

# %%
df.loc[df.Age>UB_Age,'Age']
# Out:
# Series([], Name: Age, dtype: int64)

# %%
df.loc[df.Age<LB_Age,'Age']
# Out:
# Series([], Name: Age, dtype: int64)

# %% [markdown]
# SO THERE IS NO NULL VALUES IN AGE COLUMN

# %% [markdown]
# ## RestingBP

# %%
stats.iqr(df.RestingBP)
# Out:
# 20.0

# %%
IQR_RestingBP=stats.iqr(df.RestingBP)

# %%
import numpy as np

# %%
Q1_RestingBP = np.percentile(df.RestingBP,25)
Q3_RestingBP = np.percentile(df.RestingBP,75)
print(Q1_RestingBP)
print(Q3_RestingBP)
# Out:
# 120.0
# 140.0

# %%
 Q1_RestingBP- 1.5*(IQR_RestingBP)
# Out:
# 90.0

# %%
Q3_RestingBP+1.5*(IQR_RestingBP)
# Out:
# 170.0

# %%
LB_RestingBP=Q1_RestingBP- 1.5*(IQR_RestingBP)
UB_RestingBP=Q3_RestingBP+1.5*(IQR_RestingBP)

# %%
df[(df.RestingBP>LB_RestingBP) &(df.RestingBP<UB_RestingBP)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [876 rows x 16 columns]

# %%
df.loc[df.RestingBP>UB_RestingBP,'RestingBP']
# Out:
# 109    190
# 123    180
# 189    180
# 190    180
# 241    200
# 274    180
# 275    180
# 278    180
# 365    200
# 372    185
# 399    200
# 411    180
# 423    180
# 475    178
# 550    172
# 585    180
# 592    190
# 673    174
# 702    178
# 725    180
# 732    200
# 759    192
# 774    178
# 780    180
# 855    180
# 880    172
# Name: RestingBP, dtype: int64

# %%
df.loc[df.RestingBP<LB_RestingBP,'RestingBP']
# Out:
# 314    80
# 449     0
# Name: RestingBP, dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(x=df.RestingBP)
# Out:
# <Axes: xlabel='RestingBP'>

# %% [markdown]
# ### CHECKING PERCENTAGE OF OUTLIER --- WHEN THE OUTLIER VALUE LESS THAN 5 , THEN SHOULD HANDLE OUTLIERS

# %%
((918-876)/918)*100
# Out:
# 4.57516339869281

# %%
df.RestingBP.median()
# Out:
# 130.0

# %%
df.loc[df.RestingBP>UB_RestingBP,'RestingBP']=130

# %%
df.loc[df.RestingBP<LB_RestingBP,'RestingBP']=130

# %%
df.loc[df.RestingBP>UB_RestingBP,'RestingBP']
# Out:
# Series([], Name: RestingBP, dtype: int64)

# %%
df.loc[df.RestingBP<LB_RestingBP,'RestingBP']
# Out:
# Series([], Name: RestingBP, dtype: int64)

# %%
sns.boxplot(x=df.RestingBP)
# Out:
# <Axes: xlabel='RestingBP'>

# %% [markdown]
# ## Cholesterol

# %%
stats.iqr(df.Cholesterol)
# Out:
# 93.75

# %%
IQR_Cholesterol=stats.iqr(df.Cholesterol)

# %%
Q1_Cholesterol = np.percentile(df.Cholesterol,25)
Q3_Cholesterol = np.percentile(df.Cholesterol,75)
print(Q1_Cholesterol)
print(Q3_Cholesterol)
# Out:
# 173.25
# 267.0

# %%
Q1_Cholesterol- 1.5*(IQR_Cholesterol)
# Out:
# 32.625

# %%
Q3_Cholesterol+ 1.5*(IQR_Cholesterol)
# Out:
# 407.625

# %%
LB_Cholesterol=Q1_Cholesterol- 1.5*(IQR_Cholesterol)
UB_Cholesterol=Q3_Cholesterol+1.5*(IQR_Cholesterol)

# %%
df[(df.Cholesterol>LB_Cholesterol) &(df.Cholesterol<UB_Cholesterol)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [735 rows x 16 columns]

# %%
df.loc[df.Cholesterol>UB_Cholesterol,'Cholesterol']
# Out:
# 28     468
# 30     518
# 69     412
# 76     529
# 103    466
# 149    603
# 250    491
# 496    458
# 616    564
# 667    417
# 796    409
# Name: Cholesterol, dtype: int64

# %%
df.loc[df.Cholesterol<LB_Cholesterol,'Cholesterol']
# Out:
# 293    0
# 294    0
# 295    0
# 296    0
# 297    0
#       ..
# 514    0
# 515    0
# 518    0
# 535    0
# 536    0
# Name: Cholesterol, Length: 172, dtype: int64

# %%
import seaborn as sns

# %%
sns.boxplot(x=df.Cholesterol)
# Out:
# <Axes: xlabel='Cholesterol'>

# %%
#percentage 
((918-735)/918)*100                  #the percentage of outliers is more than 5% so, we don't handle ouliers for Cholesterol
# Out:
# 19.934640522875817

# %% [markdown]
# ## FastingBS

# %%
stats.iqr(df.FastingBS)
# Out:
# 0.0

# %%
IQR_FastingBS=stats.iqr(df.FastingBS)

# %%
Q1_FastingBS = np.percentile(df.FastingBS,25)
Q3_FastingBS = np.percentile(df.FastingBS,75)
print(Q1_FastingBS)
print(Q3_FastingBS)
# Out:
# 0.0
# 0.0

# %%
Q1_FastingBS- 1.5*(IQR_FastingBS)
# Out:
# 0.0

# %% [markdown]
# THERE IS NO OUTLIERS FOR FASTINGBS COLUMN

# %% [markdown]
# ## MaxHR

# %%
stats.iqr(df.MaxHR)
# Out:
# 36.0

# %%
IQR_MaxHR=stats.iqr(df.MaxHR)

# %%
Q1_MaxHR = np.percentile(df.MaxHR,25)
Q3_MaxHR = np.percentile(df.MaxHR,75)
print(Q1_MaxHR)
print(Q3_MaxHR)
# Out:
# 120.0
# 156.0

# %%
Q1_MaxHR- 1.5*(IQR_MaxHR)
# Out:
# 66.0

# %%
Q3_MaxHR+ 1.5*(IQR_MaxHR)
# Out:
# 210.0

# %%
LB_MaxHR=Q1_MaxHR- 1.5*(IQR_MaxHR)
UB_MaxHR=Q3_MaxHR+ 1.5*(IQR_MaxHR)

# %%
df[(df.MaxHR>LB_MaxHR) &(df.MaxHR<UB_MaxHR)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [916 rows x 16 columns]

# %%
df.loc[df.MaxHR>UB_MaxHR,'MaxHR']
# Out:
# Series([], Name: MaxHR, dtype: int64)

# %%
df.loc[df.MaxHR<LB_MaxHR,'MaxHR']
# Out:
# 370    63
# 390    60
# Name: MaxHR, dtype: int64

# %%
import seaborn as sns
sns.boxplot(x=df.MaxHR)
# Out:
# <Axes: xlabel='MaxHR'>

# %%
#percentage 
((918-916)/918)*100
# Out:
# 0.2178649237472767

# %%
df.MaxHR.median()
# Out:
# 138.0

# %%
df.loc[df.MaxHR<LB_MaxHR,'MaxHR']=138

# %%
df.loc[df.MaxHR<LB_MaxHR,'MaxHR']
# Out:
# Series([], Name: MaxHR, dtype: int64)

# %%
sns.boxplot(x=df.RestingBP)
# Out:
# <Axes: xlabel='RestingBP'>

# %% [markdown]
# ## HeartDisease

# %%
stats.iqr(df.HeartDisease)
# Out:
# 1.0

# %%
IQR_HeartDisease=stats.iqr(df.HeartDisease)

# %%
Q1_HeartDisease= np.percentile(df.HeartDisease,25)
Q3_HeartDisease = np.percentile(df.HeartDisease,75)
print(Q1_HeartDisease)
print(Q3_HeartDisease)
# Out:
# 0.0
# 1.0

# %%
Q1_HeartDisease- 1.5*(IQR_HeartDisease)
# Out:
# -1.5

# %%
Q3_HeartDisease+1.5*(IQR_HeartDisease)
# Out:
# 2.5

# %%
LB_HeartDisease=Q1_HeartDisease- 1.5*(IQR_HeartDisease)
UB_HeartDisease=Q3_HeartDisease+1.5*(IQR_HeartDisease)

# %%
df[(df.HeartDisease>LB_HeartDisease) &(df.HeartDisease<UB_HeartDisease)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [918 rows x 16 columns]

# %%
df.loc[df.HeartDisease>UB_HeartDisease,'HeartDisease']
# Out:
# Series([], Name: HeartDisease, dtype: int64)

# %%
df.loc[df.HeartDisease<LB_HeartDisease,'HeartDisease']
# Out:
# Series([], Name: HeartDisease, dtype: int64)

# %% [markdown]
# ## Oldpeak

# %%
stats.iqr(df.Oldpeak)
# Out:
# 1.5

# %%
IQR_Oldpeak=stats.iqr(df.Oldpeak)

# %%
Q1_Oldpeak= np.percentile(df.Oldpeak,25)
Q3_Oldpeak = np.percentile(df.Oldpeak,75)
print(Q1_Oldpeak)
print(Q3_Oldpeak)
# Out:
# 0.0
# 1.5

# %%
Q1_Oldpeak- 1.5*(IQR_Oldpeak)
# Out:
# -2.25

# %%
Q3_Oldpeak+ 1.5*(IQR_Oldpeak)
# Out:
# 3.75

# %%
LB_Oldpeak=Q1_Oldpeak- 1.5*(IQR_Oldpeak)
UB_Oldpeak=Q3_Oldpeak+ 1.5*(IQR_Oldpeak)

# %%
df[(df.Oldpeak>LB_Oldpeak) &(df.Oldpeak<UB_Oldpeak)]
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  Age  \
# 0            False           True          False         False      True   40
# 1            False          False           True         False     False   49
# 2             True           True          False         False      True   37
# 3            False          False          False         False     False   48
# 4            False          False           True         False      True   54
# ..             ...            ...            ...           ...       ...  ...
# 913          False          False          False          True      True   45
# 914          False          False          False         False      True   68
# 915          False          False          False         False      True   57
# 916          False           True          False         False     False   57
# 917          False          False           True         False      True   38
#
#      RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# 0          140          289          0    172      0.0             0
# 1          160          180          0    156      1.0             1
# 2          130          283          0     98      0.0             0
# 3          138          214          0    108      1.5             1
# 4          150          195          0    122      0.0             0
# ..         ...          ...        ...    ...      ...           ...
# 913        110          264          0    132      1.2             1
# 914        144          193          1    141      3.4             1
# 915        130          131          0    115      1.2             1
# 916        130          236          0    174      0.0             1
# 917        138          175          0    173      0.0             0
#
# [902 rows x 16 columns]

# %%
df.loc[df.Oldpeak>UB_Oldpeak,'Oldpeak']
# Out:
# 68     4.0
# 166    5.0
# 500    4.0
# 521    4.0
# 537    4.0
# 559    4.0
# 624    4.0
# 702    4.2
# 732    4.0
# 771    5.6
# 775    3.8
# 791    4.2
# 850    6.2
# 900    4.4
# 908    4.0
# Name: Oldpeak, dtype: float64

# %%
df.loc[df.Oldpeak<LB_Oldpeak,'Oldpeak']
# Out:
# 324   -2.6
# Name: Oldpeak, dtype: float64

# %%
import seaborn as sns
sns.boxplot(x=df.Oldpeak)
# Out:
# <Axes: xlabel='Oldpeak'>

# %%
#percentage 
((918-902)/918)*100
# Out:
# 1.7429193899782136

# %%
df.Oldpeak.median()
# Out:
# 0.6

# %%
df.loc[df.Oldpeak<LB_Oldpeak,'Oldpeak']=0.6

# %%
df.loc[df.Oldpeak>UB_Oldpeak,'Oldpeak']=0.6

# %%
df.loc[df.Oldpeak<LB_Oldpeak,'Oldpeak']
# Out:
# Series([], Name: Oldpeak, dtype: float64)

# %%
df.loc[df.Oldpeak>UB_Oldpeak,'Oldpeak']
# Out:
# Series([], Name: Oldpeak, dtype: float64)

# %%
sns.boxplot(x=df.Oldpeak)
# Out:
# <Axes: xlabel='Oldpeak'>

# %% [markdown]
# ## Scaling --- to bring all int values to same scalar

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()
df[['Age','RestingBP','Cholesterol','MaxHR']]=scale.fit_transform(df[['Age','RestingBP','Cholesterol','MaxHR']])

# %%
df
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  \
# 0            False           True          False         False      True
# 1            False          False           True         False     False
# 2             True           True          False         False      True
# 3            False          False          False         False     False
# 4            False          False           True         False      True
# ..             ...            ...            ...           ...       ...
# 913          False          False          False          True      True
# 914          False          False          False         False      True
# 915          False          False          False         False      True
# 916          False           True          False         False     False
# 917          False          False           True         False      True
#
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR  Oldpeak  \
# 0    0.244898   0.615385     0.479270          0  0.777778      0.0
# 1    0.428571   0.871795     0.298507          0  0.659259      1.0
# 2    0.183673   0.487179     0.469320          0  0.229630      0.0
# 3    0.408163   0.589744     0.354892          0  0.303704      1.5
# 4    0.530612   0.743590     0.323383          0  0.407407      0.0
# ..        ...        ...          ...        ...       ...      ...
# 913  0.346939   0.230769     0.437811          0  0.481481      1.2
# 914  0.816327   0.666667     0.320066          1  0.548148      3.4
# 915  0.591837   0.487179     0.217247          0  0.355556      1.2
# 916  0.591837   0.487179     0.391376          0  0.792593      0.0
# 917  0.204082   0.589744     0.290216          0  0.785185      0.0
#
#      HeartDisease
# 0               0
# 1               1
# 2               0
# 3               1
# 4               0
# ..            ...
# 913             1
# 914             1
# 915             1
# 916             1
# 917             0
#
# [918 rows x 16 columns]

# %%
## Target and predictor seperation
x=df.iloc[:,:-1]               # x -- input features(independent values)
y=df.HeartDisease              # y -- target column(dependent values)

# %%
x
# Out:
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_Y  RestingECG_Normal  \
# 0            False         True             False               True
# 1             True        False             False               True
# 2            False         True             False              False
# 3             True        False              True               True
# 4            False         True             False               True
# ..             ...          ...               ...                ...
# 913           True        False             False               True
# 914           True        False             False               True
# 915           True        False              True               True
# 916           True        False             False              False
# 917          False         True             False               True
#
#      RestingECG_ST  ChestPain_ATA  ChestPain_NAP  ChestPain_TA  Gender_M  \
# 0            False           True          False         False      True
# 1            False          False           True         False     False
# 2             True           True          False         False      True
# 3            False          False          False         False     False
# 4            False          False           True         False      True
# ..             ...            ...            ...           ...       ...
# 913          False          False          False          True      True
# 914          False          False          False         False      True
# 915          False          False          False         False      True
# 916          False           True          False         False     False
# 917          False          False           True         False      True
#
#           Age  RestingBP  Cholesterol  FastingBS     MaxHR  Oldpeak
# 0    0.244898   0.615385     0.479270          0  0.777778      0.0
# 1    0.428571   0.871795     0.298507          0  0.659259      1.0
# 2    0.183673   0.487179     0.469320          0  0.229630      0.0
# 3    0.408163   0.589744     0.354892          0  0.303704      1.5
# 4    0.530612   0.743590     0.323383          0  0.407407      0.0
# ..        ...        ...          ...        ...       ...      ...
# 913  0.346939   0.230769     0.437811          0  0.481481      1.2
# 914  0.816327   0.666667     0.320066          1  0.548148      3.4
# 915  0.591837   0.487179     0.217247          0  0.355556      1.2
# 916  0.591837   0.487179     0.391376          0  0.792593      0.0
# 917  0.204082   0.589744     0.290216          0  0.785185      0.0
#
# [918 rows x 15 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
## train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=7)

# %% [markdown]
# * if target cloumn datatype, values are finite --- classifer
# * if target cloumn datatype, values are infinite continues --- regression

# %% [markdown]
# ## Model Creation

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)             # 'fit' is used to train Ml model for a fixed no.of epochs(iterations over the entire dataset)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import accuracy_score,classification_report
y_pred = model.predict(x_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.7663043478260869

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75        85
#            1       0.80      0.76      0.78        99
#
#     accuracy                           0.77       184
#    macro avg       0.77      0.77      0.77       184
# weighted avg       0.77      0.77      0.77       184

# %% [markdown]
# ## HOW CLASSIFICATION METRICES WORK

# %% [markdown]
#                                                     300(0'S AND 1'S)           -- (0--->POSITIVE,1--->NEGATIVE)
#                                                      |
#                         _________________________________________________________________________________
#                         |                                                                                |
#                        170 (0'S) ,  (-VE)                                                             130(1'S) , (+VE)
#         (MODELPREDICTS) |                                                                                |
#                  ____________________                                                              ___________________
#                 |                    |                                                             |                  |
#                150  (0'S)            20 (1'S)                                                     90 (1'S)            140  (0'S)
#             (TRUE POSITIVE (TP))     (FALSE NEGATIVE(FP))                                   (TRUE NEGATIVE(TN))  (FALSE POSITIVE(FP))

# %% [markdown]
# * CLASSIFICATION METRICES
#
#    * Accuracy score = TP+TN/TP+TN+FP+FN
#    * Recall = TP/TP+FN
#    * Precisiom = TP/TP+FP
#    * f1-score = 2*(P*R/P+R)       AND Recall is inversely proposional to precision

# %%
## Tree structure
from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(0.5933354878597122, 0.96875, 'x[1] <= 0.5\ngini = 0.492\nsamples = 734\nvalue = [320, 414]'),
#  Text(0.39080766636690645, 0.90625, 'x[13] <= 0.619\ngini = 0.291\nsamples = 424\nvalue = [75, 349]'),
#  Text(0.49207157711330934, 0.9375, 'True  '),
#  Text(0.2204642535971223, 0.84375, 'x[8] <= 0.5\ngini = 0.211\nsamples = 350\nvalue = [42, 308]'),
#  Text(0.05755395683453238, 0.78125, 'x[2] <= 0.5\ngini = 0.458\nsamples = 45\nvalue = [16.0, 29.0]'),
#  Text(0.02877697841726619, 0.71875, 'x[10] <= 0.538\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.014388489208633094, 0.65625, 'x[13] <= 0.226\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.007194244604316547, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02158273381294964, 0.59375, 'x[13] <= 0.611\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.014388489208633094, 0.53125, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.02877697841726619, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04316546762589928, 0.65625, 'x[4] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.03597122302158273, 0.59375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.050359712230215826, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08633093525179857, 0.71875, 'x[9] <= 0.52\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.07194244604316546, 0.65625, 'x[9] <= 0.48\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.06474820143884892, 0.59375, 'x[11] <= 0.525\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.05755395683453238, 0.53125, 'x[10] <= 0.679\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.050359712230215826, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.06474820143884892, 0.46875, 'x[13] <= 0.541\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05755395683453238, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07194244604316546, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07194244604316546, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07913669064748201, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10071942446043165, 0.65625, 'x[11] <= 0.568\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.09352517985611511, 0.59375, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.1079136690647482, 0.59375, 'x[4] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10071942446043165, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11510791366906475, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38337455035971224, 0.78125, 'x[7] <= 0.5\ngini = 0.156\nsamples = 305\nvalue = [26, 279]'),
#  Text(0.3279001798561151, 0.71875, 'x[5] <= 0.5\ngini = 0.138\nsamples = 294\nvalue = [22, 272]'),
#  Text(0.26011690647482016, 0.65625, 'x[6] <= 0.5\ngini = 0.119\nsamples = 283\nvalue = [18, 265]'),
#  Text(0.16052158273381295, 0.59375, 'x[13] <= 0.026\ngini = 0.089\nsamples = 237\nvalue = [11, 226]'),
#  Text(0.12949640287769784, 0.53125, 'x[3] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1223021582733813, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1366906474820144, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19154676258992806, 0.53125, 'x[13] <= 0.433\ngini = 0.081\nsamples = 235\nvalue = [10, 225]'),
#  Text(0.1510791366906475, 0.46875, 'x[9] <= 0.704\ngini = 0.04\nsamples = 147\nvalue = [3.0, 144.0]'),
#  Text(0.1366906474820144, 0.40625, 'x[14] <= 0.55\ngini = 0.018\nsamples = 108\nvalue = [1, 107]'),
#  Text(0.12949640287769784, 0.34375, 'x[14] <= 0.25\ngini = 0.062\nsamples = 31\nvalue = [1, 30]'),
#  Text(0.1223021582733813, 0.28125, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.1366906474820144, 0.28125, 'x[11] <= 0.19\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.12949640287769784, 0.21875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.14388489208633093, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14388489208633093, 0.34375, 'gini = 0.0\nsamples = 77\nvalue = [0, 77]'),
#  Text(0.16546762589928057, 0.40625, 'x[10] <= 0.474\ngini = 0.097\nsamples = 39\nvalue = [2, 37]'),
#  Text(0.15827338129496402, 0.34375, 'x[10] <= 0.41\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.1510791366906475, 0.28125, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.16546762589928057, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17266187050359713, 0.34375, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.23201438848920863, 0.46875, 'x[13] <= 0.456\ngini = 0.146\nsamples = 88\nvalue = [7, 81]'),
#  Text(0.2014388489208633, 0.40625, 'x[9] <= 0.582\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.18705035971223022, 0.34375, 'x[9] <= 0.276\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.17985611510791366, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19424460431654678, 0.28125, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.2158273381294964, 0.34375, 'x[9] <= 0.745\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.20863309352517986, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22302158273381295, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26258992805755393, 0.40625, 'x[9] <= 0.602\ngini = 0.104\nsamples = 73\nvalue = [4, 69]'),
#  Text(0.25539568345323743, 0.34375, 'x[0] <= 0.5\ngini = 0.176\nsamples = 41\nvalue = [4, 37]'),
#  Text(0.23741007194244604, 0.28125, 'x[9] <= 0.459\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2302158273381295, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2446043165467626, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2733812949640288, 0.28125, 'x[9] <= 0.582\ngini = 0.142\nsamples = 39\nvalue = [3, 36]'),
#  Text(0.2589928057553957, 0.21875, 'x[11] <= 0.394\ngini = 0.105\nsamples = 36\nvalue = [2, 34]'),
#  Text(0.2517985611510791, 0.15625, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(0.26618705035971224, 0.15625, 'x[10] <= 0.391\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.2589928057553957, 0.09375, 'x[14] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2517985611510791, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.26618705035971224, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2733812949640288, 0.09375, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.28776978417266186, 0.21875, 'x[10] <= 0.538\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2805755395683453, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2949640287769784, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2697841726618705, 0.34375, 'gini = 0.0\nsamples = 32\nvalue = [0, 32]'),
#  Text(0.3597122302158273, 0.59375, 'x[10] <= 0.115\ngini = 0.258\nsamples = 46\nvalue = [7, 39]'),
#  Text(0.35251798561151076, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3669064748201439, 0.53125, 'x[10] <= 0.494\ngini = 0.231\nsamples = 45\nvalue = [6, 39]'),
#  Text(0.35251798561151076, 0.46875, 'x[11] <= 0.52\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.34532374100719426, 0.40625, 'x[14] <= 1.55\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.3381294964028777, 0.34375, 'x[14] <= 1.15\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.3237410071942446, 0.28125, 'x[11] <= 0.404\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.31654676258992803, 0.21875, 'x[13] <= 0.226\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.30935251798561153, 0.15625, 'x[13] <= 0.159\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.302158273381295, 0.09375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.31654676258992803, 0.09375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3237410071942446, 0.15625, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.33093525179856115, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35251798561151076, 0.28125, 'x[13] <= 0.578\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.34532374100719426, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3597122302158273, 0.21875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35251798561151076, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3597122302158273, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.381294964028777, 0.46875, 'x[9] <= 0.888\ngini = 0.083\nsamples = 23\nvalue = [1, 22]'),
#  Text(0.37410071942446044, 0.40625, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.38848920863309355, 0.40625, 'x[14] <= 0.8\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.381294964028777, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39568345323741005, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39568345323741005, 0.65625, 'x[2] <= 0.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.38848920863309355, 0.59375, 'x[10] <= 0.295\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.381294964028777, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39568345323741005, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4028776978417266, 0.59375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.43884892086330934, 0.71875, 'x[9] <= 0.704\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.4244604316546763, 0.65625, 'x[11] <= 0.443\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.4172661870503597, 0.59375, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.4316546762589928, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45323741007194246, 0.65625, 'x[14] <= 0.05\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4460431654676259, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.460431654676259, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5611510791366906, 0.84375, 'x[6] <= 0.5\ngini = 0.494\nsamples = 74\nvalue = [33, 41]'),
#  Text(0.5215827338129496, 0.78125, 'x[5] <= 0.5\ngini = 0.453\nsamples = 49\nvalue = [17.0, 32.0]'),
#  Text(0.49640287769784175, 0.71875, 'x[11] <= 0.488\ngini = 0.361\nsamples = 38\nvalue = [9, 29]'),
#  Text(0.48201438848920863, 0.65625, 'x[13] <= 0.633\ngini = 0.264\nsamples = 32\nvalue = [5, 27]'),
#  Text(0.4748201438848921, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4892086330935252, 0.59375, 'x[13] <= 0.881\ngini = 0.225\nsamples = 31\nvalue = [4, 27]'),
#  Text(0.48201438848920863, 0.53125, 'x[9] <= 0.561\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.4748201438848921, 0.46875, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.4892086330935252, 0.46875, 'x[11] <= 0.396\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.48201438848920863, 0.40625, 'x[12] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.4748201438848921, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4892086330935252, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.49640287769784175, 0.40625, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.49640287769784175, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5107913669064749, 0.65625, 'x[12] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.5035971223021583, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5179856115107914, 0.59375, 'x[11] <= 0.523\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5107913669064749, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5251798561151079, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5467625899280576, 0.71875, 'x[9] <= 0.592\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.539568345323741, 0.65625, 'x[14] <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.5323741007194245, 0.59375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5467625899280576, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5539568345323741, 0.65625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6007194244604317, 0.78125, 'x[10] <= 0.5\ngini = 0.461\nsamples = 25\nvalue = [16, 9]'),
#  Text(0.5827338129496403, 0.71875, 'x[11] <= 0.117\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(0.5683453237410072, 0.65625, 'x[14] <= 2.8\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5611510791366906, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5755395683453237, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5971223021582733, 0.65625, 'x[10] <= 0.314\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.5899280575539568, 0.59375, 'x[13] <= 0.707\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.5827338129496403, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5971223021582733, 0.53125, 'x[10] <= 0.231\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5899280575539568, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.60431654676259, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.60431654676259, 0.59375, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.6187050359712231, 0.71875, 'x[11] <= 0.436\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.6115107913669064, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6258992805755396, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.795863309352518, 0.90625, 'x[11] <= 0.083\ngini = 0.331\nsamples = 310\nvalue = [245, 65]'),
#  Text(0.6945993986061152, 0.9375, '  False'),
#  Text(0.6798561151079137, 0.84375, 'x[12] <= 0.5\ngini = 0.394\nsamples = 37\nvalue = [10, 27]'),
#  Text(0.6726618705035972, 0.78125, 'x[14] <= 0.25\ngini = 0.499\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.6546762589928058, 0.71875, 'x[2] <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.6402877697841727, 0.65625, 'x[10] <= 0.744\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.6330935251798561, 0.59375, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6474820143884892, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6690647482014388, 0.65625, 'x[10] <= 0.628\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6618705035971223, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6762589928057554, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6906474820143885, 0.71875, 'x[9] <= 0.633\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.6834532374100719, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.697841726618705, 0.65625, 'x[14] <= 0.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6906474820143885, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7050359712230215, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6870503597122302, 0.78125, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.9118705035971223, 0.84375, 'x[2] <= 0.5\ngini = 0.24\nsamples = 273\nvalue = [235, 38]'),
#  Text(0.8381294964028777, 0.78125, 'x[9] <= 0.582\ngini = 0.161\nsamples = 238\nvalue = [217, 21]'),
#  Text(0.7805755395683454, 0.71875, 'x[10] <= 0.346\ngini = 0.101\nsamples = 187\nvalue = [177, 10]'),
#  Text(0.7338129496402878, 0.65625, 'x[11] <= 0.288\ngini = 0.266\nsamples = 38\nvalue = [32, 6]'),
#  Text(0.7194244604316546, 0.59375, 'x[3] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7122302158273381, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7266187050359713, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7482014388489209, 0.59375, 'x[13] <= 0.622\ngini = 0.202\nsamples = 35\nvalue = [31, 4]'),
#  Text(0.7410071942446043, 0.53125, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.7553956834532374, 0.53125, 'x[5] <= 0.5\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.7482014388489209, 0.46875, 'x[9] <= 0.296\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.7410071942446043, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7553956834532374, 0.40625, 'x[8] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.7482014388489209, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.762589928057554, 0.34375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.762589928057554, 0.46875, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.8273381294964028, 0.65625, 'x[13] <= 0.93\ngini = 0.052\nsamples = 149\nvalue = [145, 4]'),
#  Text(0.8057553956834532, 0.59375, 'x[14] <= 0.7\ngini = 0.04\nsamples = 147\nvalue = [144.0, 3.0]'),
#  Text(0.7841726618705036, 0.53125, 'x[10] <= 0.756\ngini = 0.015\nsamples = 130\nvalue = [129, 1]'),
#  Text(0.7769784172661871, 0.46875, 'gini = 0.0\nsamples = 120\nvalue = [120, 0]'),
#  Text(0.7913669064748201, 0.46875, 'x[13] <= 0.822\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.7841726618705036, 0.40625, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7985611510791367, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8273381294964028, 0.53125, 'x[10] <= 0.455\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.8201438848920863, 0.46875, 'x[9] <= 0.51\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.8129496402877698, 0.40625, 'x[9] <= 0.296\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8057553956834532, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8201438848920863, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8273381294964028, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8345323741007195, 0.46875, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.8489208633093526, 0.59375, 'x[13] <= 0.974\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.841726618705036, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8561151079136691, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.89568345323741, 0.71875, 'x[13] <= 0.626\ngini = 0.338\nsamples = 51\nvalue = [40, 11]'),
#  Text(0.8705035971223022, 0.65625, 'x[11] <= 0.432\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.8633093525179856, 0.59375, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.8776978417266187, 0.59375, 'x[11] <= 0.441\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.8705035971223022, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8848920863309353, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.920863309352518, 0.65625, 'x[3] <= 0.5\ngini = 0.483\nsamples = 22\nvalue = [13, 9]'),
#  Text(0.9064748201438849, 0.59375, 'x[13] <= 0.819\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.8992805755395683, 0.53125, 'x[7] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.8920863309352518, 0.46875, 'x[9] <= 0.602\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.8848920863309353, 0.40625, 'x[8] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8776978417266187, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8920863309352518, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8992805755395683, 0.40625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9064748201438849, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9136690647482014, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.935251798561151, 0.59375, 'x[13] <= 0.663\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.9280575539568345, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9424460431654677, 0.53125, 'x[7] <= 0.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.935251798561151, 0.46875, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.9496402877697842, 0.46875, 'x[11] <= 0.368\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9424460431654677, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9568345323741008, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9856115107913669, 0.78125, 'x[13] <= 0.711\ngini = 0.5\nsamples = 35\nvalue = [18, 17]'),
#  Text(0.9784172661870504, 0.71875, 'x[8] <= 0.5\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.9712230215827338, 0.65625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9856115107913669, 0.65625, 'x[6] <= 0.5\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.9784172661870504, 0.59375, 'x[13] <= 0.548\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.9712230215827338, 0.53125, 'x[14] <= 0.05\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.9640287769784173, 0.46875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9784172661870504, 0.46875, 'x[7] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.9712230215827338, 0.40625, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.9856115107913669, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9856115107913669, 0.53125, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.9928057553956835, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9928057553956835, 0.71875, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]')]

# %% [markdown]
# ## TO IMPROVE ACCURACY

# %%
y_pred_train=model.predict(x_train)
accuracy_score(y_pred_train,y_train)
# Out:
# 1.0

# %%
model = DecisionTreeClassifier(max_depth=3)    #we change max_Depth to get generalised model
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
y_pred=model.predict(x_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.8858695652173914

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        85
#            1       0.91      0.87      0.89        99
#
#     accuracy                           0.89       184
#    macro avg       0.89      0.89      0.89       184
# weighted avg       0.89      0.89      0.89       184

# %%
from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 0.5\ngini = 0.492\nsamples = 734\nvalue = [320, 414]'),
#  Text(0.25, 0.625, 'x[13] <= 0.619\ngini = 0.291\nsamples = 424\nvalue = [75, 349]'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'x[8] <= 0.5\ngini = 0.211\nsamples = 350\nvalue = [42, 308]'),
#  Text(0.0625, 0.125, 'gini = 0.458\nsamples = 45\nvalue = [16.0, 29.0]'),
#  Text(0.1875, 0.125, 'gini = 0.156\nsamples = 305\nvalue = [26, 279]'),
#  Text(0.375, 0.375, 'x[6] <= 0.5\ngini = 0.494\nsamples = 74\nvalue = [33, 41]'),
#  Text(0.3125, 0.125, 'gini = 0.453\nsamples = 49\nvalue = [17.0, 32.0]'),
#  Text(0.4375, 0.125, 'gini = 0.461\nsamples = 25\nvalue = [16, 9]'),
#  Text(0.75, 0.625, 'x[11] <= 0.083\ngini = 0.331\nsamples = 310\nvalue = [245, 65]'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[12] <= 0.5\ngini = 0.394\nsamples = 37\nvalue = [10, 27]'),
#  Text(0.5625, 0.125, 'gini = 0.499\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.6875, 0.125, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.875, 0.375, 'x[2] <= 0.5\ngini = 0.24\nsamples = 273\nvalue = [235, 38]'),
#  Text(0.8125, 0.125, 'gini = 0.161\nsamples = 238\nvalue = [217, 21]'),
#  Text(0.9375, 0.125, 'gini = 0.5\nsamples = 35\nvalue = [18, 17]')]

# %%
y_pred_train=model.predict(x_train)
accuracy_score(y_pred_train,y_train)
# Out:
# 0.8433242506811989

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# which feature is having ,how much importance based on training and target values

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
imp=model.feature_importances_
indices = np.argsort(imp)
features = x_train.columns

# %%
plt.figure(figsize=(10,15))
plt.title('Feature Importance')
plt.barh(range(len(indices)),imp[indices],align='center',color='Green')
plt.yticks(range(len(indices)),[features[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# * hyperparameter tuning is used to improve accuracy , hyperparameter tuning is having 2 algorithms " RandomizedSearchCV,GridSearchCV"

# %%
params = {'max_depth':[3,5,9,10,15],'criterion':['gini','entropy']}

# %% [markdown]
# ### RandomizedSearchCV

# %%
## hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV
rscv = RandomizedSearchCV(model, param_distributions=params)
rscv.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(estimator=DecisionTreeClassifier(max_depth=3),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [3, 5, 9, 10, 15]})

# %%
rscv.best_score_
# Out:
# 0.8474140341067933

# %%
rscv.best_params_
# Out:
# {'max_depth': 5, 'criterion': 'entropy'}

# %% [markdown]
# ### GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
gscv = GridSearchCV(model, param_grid=params)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(max_depth=3),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 9, 10, 15]})

# %%
gscv.best_score_
# Out:
# 0.8460441710930947

# %%
gscv.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 5}

# %%
model = DecisionTreeClassifier(max_depth=5, criterion='entropy')
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
y_pred_train=model.predict(x_train)
accuracy_score(y_pred_train,y_train)
# Out:
# 0.8869209809264306

# %%
y_pred=model.predict(x_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.8532608695652174

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84        81
#            1       0.90      0.83      0.86       103
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.86      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %%
import joblib

# %%
#save model
joblib.dump(model, "decision_tree_model.pkl")
# Out:
# ['decision_tree_model.pkl']

# %% [markdown]
# ## Gradio Interface

# %%
! pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\jayav\anaconda4346\lib\site-packages (5.31.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.1 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (1.10.1)
# Requirement already satisfied: groovy~=0.1 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.32.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (2.8.2)
# Requirement already satisfied: pydub in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.11.12)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in c:\users\jayav\anaconda4346\lib\site-packages (from gradio-client==1.10.1->gradio) (2024.6.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\jayav\anaconda4346\lib\site-packages (from gradio-client==1.10.1->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\jayav\anaconda4346\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jayav\anaconda4346\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\jayav\anaconda4346\lib\site-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\jayav\anaconda4346\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\jayav\anaconda4346\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\jayav\anaconda4346\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\jayav\anaconda4346\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\jayav\anaconda4346\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jayav\anaconda4346\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jayav\anaconda4346\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jayav\anaconda4346\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jayav\anaconda4346\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\jayav\anaconda4346\lib\site-packages (from pydantic<2.12,>=2.0->gradio) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\jayav\anaconda4346\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\jayav\anaconda4346\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jayav\anaconda4346\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: colorama in c:\users\jayav\anaconda4346\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\jayav\anaconda4346\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jayav\anaconda4346\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jayav\anaconda4346\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jayav\anaconda4346\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jayav\anaconda4346\lib\site-packages (from requests->huggingface-hub>=0.28.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jayav\anaconda4346\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
import gradio as gr
import numpy as np

# Prediction function
def predict_heart_disease(ST_Slope_Up,Cholestal,MaxHR,ExerciseAngina_Y,Gender_M,FastingBS,ChestPain_NAP):
    input_data=np.array([[ST_Slope_Up,Cholestal,MaxHR,ExerciseAngina_Y,Gender_M,FastingBS,ChestPain_NAP]])
    prediction=model.predict(input_data)
    return "At Risk" if prediction[0]== i else "Not At Risk"

# Gradio Interface
iface=gr.Interface(
    fn=predict_heart_disease,
    inputs=[
        gr.Slider(0, 1, step=1, label="ST_Slope_Up"),
        gr.Number(label="Cholestal"),
        gr.Number(label="MaxHR"),
        gr.Slider(0,1, step=1, label="ExerciseAngina_Y"),
        gr.Slider(0,1, step=1, label="Gender_M"),
        gr.Slider(0,1, step=1, label="FastingBS"),
        gr.Slider(0,1, step=1, label="ChestPainNAP"),
    ],
    outputs="text",
    title="Heart Disease Risk Predictor"
)
iface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
